# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/processed/data_model_output.csv')
df = df[(df['is_completed'] == True) & (df['record_type_synthetic'] == False)]
# Out:
# C:\Users\USVV724227\AppData\Local\Temp\ipykernel_40564\3975912904.py:1: DtypeWarning: Columns (4,5,9,14,21,33,38,39,47,67,68,70,73,76,78,80,82,85,89,95,98,105,114,116,122,137,139,250,254,255,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,279,281,287,288,289,290,291,292,293,294,314,315,316,323,324) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/processed/data_model_output.csv')

# %%
df.head()
# Out:
#    unique_id  is_completed  is_pilot  record_type_synthetic respondentid  \
# 0          1          True     False                      0         5473
# 1          2          True     False                      0         5476
# 2          3          True     False                      0         5489
# 3          4          True     False                      0         5558
# 4          5          True     False                      0         5593
#
#   submit date_completed  interview_location interview_location_label  \
# 0   True     2024-10-04                 2.0               TERMINAL_2
# 1   True     2024-10-04                 3.0              ONBOARD_992
# 2   True     2024-10-04                 2.0               TERMINAL_2
# 3   True     2024-10-04                 2.0               TERMINAL_2
# 4   True     2024-10-04                 2.0               TERMINAL_2
#
#   interview_location_other  ...  next_flight_destination  \
# 0                      NaN  ...                      NaN
# 1                      NaN  ...                      NaN
# 2                      NaN  ...                      NaN
# 3                      NaN  ...                      NaN
# 4                      NaN  ...                      NaN
#
#   non_airport_activity_type  parking_cost_numeric previous_flight_origin  \
# 0                       2.0                 100.0                    NaN
# 1                       2.0                   NaN                    NaN
# 2                       2.0                 134.0                    NaN
# 3                       2.0                   NaN                    NaN
# 4                       2.0                   NaN                    NaN
#
#   taxi_fhv_fare_numeric  taxi_fhv_wait_numeric valid_record  \
# 0                   NaN                    NaN         True
# 1                   NaN                    NaN        False
# 2                   NaN                    NaN         True
# 3                   NaN                    NaN         True
# 4                   NaN                    NaN         True
#
#                                     validation_error validation_severity  \
# 0                                                NaN                 NaN
# 1  Prefer Not to disclose cannot be combined with...                 Low
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#    weight
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
#
# [5 rows x 326 columns]

# %%
# Filter DataFrames
df_pilot = df[df['is_pilot'] == True]
df_original = df[df['is_pilot'] == False]

# %%
def plot_histograms(col):# Create subplots
    fig, axes = plt.subplots(1, 2, figsize=(12, 9), sharey=True)

    # Plot for 'is_pilot' = True
    df_pilot[col].value_counts(normalize = True).plot(kind='bar', ax=axes[0], color='blue', alpha=0.7)
    axes[0].set_title("PILOT", fontsize=14)
    axes[0].set_xlabel(col, fontsize=12)
    axes[0].set_ylabel('Frequency', fontsize=12)

    # Plot for 'is_pilot' = False
    df_original[col].value_counts(normalize = True).plot(kind='bar', ax=axes[1], color='orange', alpha=0.7)
    axes[1].set_title("ORIGINAL", fontsize=14)
    axes[1].set_xlabel(col, fontsize=12)

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
plot_histograms('airport_terminal')

# %%
plot_histograms('main_mode_label')

# %%
plot_histograms('resident_visitor_label')

# %%
plot_histograms('access_mode_label')

# %%
plot_histograms('reverse_mode_label')

# %%
plot_histograms('nights_away_label')

# %%
plot_histograms('nights_visited_label')

# %%
plot_histograms('passenger_type_label')

# %%
df.columns
# Out:
# Index(['unique_id', 'is_completed', 'is_pilot', 'record_type_synthetic',
#        'respondentid', 'submit', 'date_completed', 'interview_location',
#        'interview_location_label', 'interview_location_other',
#        ...
#        'next_flight_destination', 'non_airport_activity_type',
#        'parking_cost_numeric', 'previous_flight_origin',
#        'taxi_fhv_fare_numeric', 'taxi_fhv_wait_numeric', 'valid_record',
#        'validation_error', 'validation_severity', 'weight'],
#       dtype='object', length=326)

# %%
plot_histograms('interview_location_label')
